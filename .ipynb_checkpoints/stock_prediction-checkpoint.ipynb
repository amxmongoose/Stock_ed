# %%
import quandl
import pandas as pd
import numpy as np
import fbprophet
import pytrends
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
import matplotlib

# %%
from stock import Stock

# %%
stock = input("What ticker?")
# Out:
# What ticker?nflx

# %%
stock = Stock(stock)
# Out:
# NFLX Stocker Initialized. Data covers 2002-05-23 00:00:00 to 2018-03-27 00:00:00.

# %%
Stock.plot_stock(self=stock, start_date=None, end_date=None, stats=['Adj. Close'], plot_type='basic')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-ab3785b078ce> in <module>()
# ----> 1 Stock.plot_stock(self=stock, start_date=None, end_date=None, stats=['Adj. Close'], plot_type='basic')
#
# ~/Desktop/Final Project/Stock_ed/stock.py in plot_stock(self, start_date, end_date, stats, plot_type)
#     182             end_date = self.max_date
#     183
# --> 184         stock_plot = self.make_df(start_date, end_date)
#     185
#     186         colors = ['r', 'b', 'g', 'y', 'c', 'm']
#
# ~/Desktop/Final Project/Stock_ed/stock.py in make_df(self, start_date, end_date, df)
#     109             df = self.stock.copy()
#     110
# --> 111         start_date, end_date = self.handle_dates(start_date, end_date)
#     112
#     113         # keep track of whether the start and end dates are in the data
#
# TypeError: 'NoneType' object is not iterable

# %%
model, model_data = stock.create_prophet_model(days=105)
# Out:
# Predicted Price on 2018-07-10 00:00:00 = $373.23

# %%
stock.evaluate_prediction()
# Out:
# Prediction Range: 2017-03-27 00:00:00 to 2018-03-27 00:00:00.
#
# Predicted price on 2018-03-24 00:00:00 = $269.99.
# Actual price on    2018-03-23 00:00:00 = $300.94.
#
# Average Absolute Error on Training Data = $4.88.
# Average Absolute Error on Testing  Data = $34.49.
#
# When the model predicted an increase, the price increased 54.12% of the time.
# When the model predicted a  decrease, the price decreased  49.09% of the time.
#
# The actual value was within the 80% confidence interval 14.80% of the time.

# %%
stock.changepoint_prior_analysis(changepoint_priors=[0.001, 0.05, 0.1, 0.2])

# %%
stock.changepoint_prior_validation(start_date='2016-01-04', 
                                    end_date='2017-01-03', 
                                    changepoint_priors=[0.001, 0.05, 0.1, 0.2])
# Out:
# Validation Range 2016-01-04 00:00:00 to 2017-01-03 00:00:00.
#
#      cps  train_err  train_range   test_err  test_range
# 0  0.001   8.220086    27.138264  21.778566   27.150825
# 1  0.050   3.622990    11.942336  58.626547   24.974841
# 2  0.100   3.041482    10.146513  69.752709   52.232528
# 3  0.200   2.811971     9.454480  77.604045   80.377498

# %%
stock.changepoint_prior_validation(start_date='2016-01-04', 
                                    end_date='2017-01-03', 
                                    changepoint_priors=[0.15, 0.2, 0.25,0.4, 0.5, 0.6])
# Out:
# Validation Range 2016-01-04 00:00:00 to 2017-01-03 00:00:00.
#
#     cps  train_err  train_range   test_err  test_range
# 0  0.15   2.874493     9.648228  78.078025   71.159498
# 1  0.20   2.811971     9.441288  77.604045   78.968756
# 2  0.25   2.826722     9.400916  75.233586   75.443702
# 3  0.40   2.437101     8.440245  69.384832  156.911759
# 4  0.50   2.361047     8.227968  66.978951  194.529075
# 5  0.60   2.325896     8.153252  64.382698  206.521465

# %%
stock.changepoint_prior_scale = 0.5

# %%
stock.evaluate_prediction()
# Out:
# Prediction Range: 2017-03-27 00:00:00 to 2018-03-27 00:00:00.
#
# Predicted price on 2018-03-24 00:00:00 = $232.14.
# Actual price on    2018-03-23 00:00:00 = $300.94.
#
# Average Absolute Error on Training Data = $3.05.
# Average Absolute Error on Testing  Data = $19.61.
#
# When the model predicted an increase, the price increased 55.69% of the time.
# When the model predicted a  decrease, the price decreased  51.22% of the time.
#
# The actual value was within the 80% confidence interval 96.80% of the time.

# %%
stock.evaluate_prediction(nshares=1000)
# Out:
# /Users/adammercier/Desktop/Final Project/stock.py:607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   test_pred_increase['pred_profit'] = prediction_profit
# You played the stock market in NFLX from 2017-03-27 00:00:00 to 2018-03-27 00:00:00 with 1000 shares.
#
# When the model predicted an increase, the price increased 55.69% of the time.
# When the model predicted a  decrease, the price decreased  51.22% of the time.
#
# The total profit using the Prophet model = $137570.00.
# The Buy and Hold strategy profit =         $156880.00.
#
# Thanks for playing the stock market!

# %%
stock.predict_future(days=10)
# Out:
# Predicted Increase:
#
#          Date    estimate    change       upper       lower
# 1  2018-03-28  322.913671  0.169939  330.146075  315.755464
# 2  2018-03-29  323.053013  0.139342  330.545346  315.755426
# 3  2018-03-30  323.857776  0.804763  331.016287  316.543341
# 5  2018-04-01  327.280646  3.422870  334.630349  320.065001
# 6  2018-04-02  328.573540  1.292894  335.453236  321.504284
# 7  2018-04-03  329.101570  0.528030  336.310687  321.997518
# 8  2018-04-04  329.364676  0.263106  336.146243  322.293921
# 9  2018-04-05  330.125777  0.761100  337.277216  323.263674
# 10 2018-04-06  331.688618  1.562841  338.978681  324.341310
#
# Predicted Decrease:
#
# Empty DataFrame
# Columns: [Date, estimate, change, upper, lower]
# Index: []

# %%
stock.predict_future(days=90)
# Out:
# Predicted Increase:
#
#          Date    estimate    change       upper       lower
# 1  2018-03-28  322.913671  0.169939  330.176297  316.167621
# 2  2018-03-29  323.053013  0.139342  329.973113  315.944195
# 3  2018-03-30  323.857776  0.804763  330.858530  316.977055
# 5  2018-04-01  327.280646  3.422870  334.328667  320.439574
# 6  2018-04-02  328.573540  1.292894  335.686093  321.278881
# 7  2018-04-03  329.101570  0.528030  336.247236  321.840413
# 8  2018-04-04  329.364676  0.263106  336.714736  321.645480
# 9  2018-04-05  330.125777  0.761100  337.861341  322.549543
# 10 2018-04-06  331.688618  1.562841  338.452049  324.378313
# 12 2018-04-08  335.044820  3.356202  342.884520  327.403966
# 13 2018-04-09  335.577856  0.533036  343.036749  327.320469
# 15 2018-04-11  335.526232  0.034455  342.806630  327.157906
# 16 2018-04-12  336.200638  0.674406  344.249749  328.184306
# 17 2018-04-13  337.405578  1.204940  345.545806  329.128743
# 19 2018-04-15  339.389722  1.984144  347.959274  330.668582
# 20 2018-04-16  339.860505  0.470783  348.162135  331.380393
# 21 2018-04-17  340.422856  0.562352  348.978509  332.703604
# 22 2018-04-18  341.300452  0.877595  350.657736  332.032606
# 23 2018-04-19  342.251778  0.951326  352.550092  332.545259
# 24 2018-04-20  342.808031  0.556253  352.586917  333.393562
# 27 2018-04-23  342.737103  0.174636  352.947984  332.206761
# 28 2018-04-24  343.584227  0.847124  354.144798  333.173106
# 29 2018-04-25  344.735844  1.151616  355.257394  333.907326
# 30 2018-04-26  345.497461  0.761617  357.320584  334.252154
# 31 2018-04-27  345.500484  0.003023  356.815371  333.920188
# 34 2018-04-30  345.682752  0.706648  358.371220  333.128796
# 35 2018-05-01  346.955340  1.272588  360.057105  333.545656
# 36 2018-05-02  348.048547  1.093207  362.273809  335.794398
